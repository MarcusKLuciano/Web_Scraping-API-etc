# %%
import requests
import pandas as pd

# %%
final=pd.DataFrame()
for j in range(1,501) :
    response=requests.get('https://api.themoviedb.org/3/movie/popular?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(j)).json()
    popularity=[]
    vote_count=[]
    original_language=[]
    title=[]
    vote_average=[]
    overview=[]
    release_date=[]

    for i in response['results'] :
        popularity.append(i['popularity'])
        vote_count.append(i['vote_count'])
        original_language.append(i['original_language'])
        title.append(i['title'])
        vote_average.append(i['vote_average'])
        overview.append(i['overview'])
        
        try:
            release_date.append(i['release_date'])
        except:
            release_date.append('NAN')

    d={'title':title, 'overview':overview, 'release_date':release_date, 'popularity':popularity, 'vote_count':vote_count}
    
    df=pd.DataFrame(d)
    
    final=final.append(df, ignore_index=True)

# %%
final
# Out:
#                                                   title  \
# 0                                              Ad Astra
# 1                                            Extraction
# 2                                         Scary Movie 6
# 3     Crayon Shin-chan: Fierceness That Invites Stor...
# 4                                             Bloodshot
# ...                                                 ...
# 9995                                Nanook of the North
# 9996                                 Sullivan's Travels
# 9997                             Species: The Awakening
# 9998                                       Frankenstein
# 9999                                        El Infierno
#
#                                                overview release_date  \
# 0     The near future, a time when both hope and har...   2019-09-17
# 1     Tyler Rake, a fearless mercenary who offers hi...   2020-04-24
# 2     [RUMORED]  The sixth and final installment of ...   2021-04-02
# 3     Shin-chan somehow travels back in time, where ...   2002-04-20
# 4     After he and his wife are murdered, marine Ray...   2020-03-05
# ...                                                 ...          ...
# 9995  This pioneering documentary film depicts the l...   1922-06-11
# 9996  Successful movie director John L. Sullivan, co...   1941-11-30
# 9997  A scientist, Dr Holander, takes his niece Mira...   2007-10-02
# 9998  An investigation into a serial killer leads tw...   2004-10-09
# 9999  Benjamin Garcia, Benny is deported from the Un...   2010-09-03
#
#       popularity  vote_count
# 0        490.159        3260
# 1        401.671        1404
# 2        339.787           0
# 3        209.405           5
# 4        189.831        2041
# ...          ...         ...
# 9995       7.634         138
# 9996       9.133         234
# 9997       9.294          87
# 9998       5.844          22
# 9999       8.586         152
#
# [10000 rows x 5 columns]

# %%
final.to_csv('movies.csv')
